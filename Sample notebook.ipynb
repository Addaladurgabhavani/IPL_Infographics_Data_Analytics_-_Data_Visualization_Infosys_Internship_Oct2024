# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\BHARGAVI\OneDrive\Documents\winemag-data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %%
data.to_csv('winemag_preprocessed.csv',index=False)

# %%
data.drop(columns=['description','designation','winery'],inplace=True)

# %%
data.tail(5)
# Out:
#         Unnamed: 0  country  points  price province region_1  \
# 129966      129966  Germany      90   28.0    Mosel      NaN
# 129967      129967       US      90   75.0   Oregon   Oregon
# 129968      129968   France      90   30.0   Alsace   Alsace
# 129969      129969   France      90   32.0   Alsace   Alsace
# 129970      129970   France      90   21.0   Alsace   Alsace
#
#                taster_name                                              title  \
# 129966  Anna Lee C. Iijima  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 129967        Paul Gregutt                  Citation 2004 Pinot Noir (Oregon)
# 129968          Roger Voss  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969          Roger Voss      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970          Roger Voss  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                variety
# 129966        Riesling
# 129967      Pinot Noir
# 129968  Gewürztraminer
# 129969      Pinot Gris
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# points                   0
# price                 8996
# region_1             21247
# taster_name          26244
#                      ...
# variety_Zinfandel        0
# variety_Zlahtina         0
# variety_Zweigelt         0
# variety_Çalkarası        0
# variety_Žilavka          0
# Length: 1180, dtype: int64

# %%
data.drop(columns=['Unnamed: 0'])
# Out:
#         points  price             region_1         taster_name  \
# 0           87    NaN                 Etna       Kerin O’Keefe
# 1           87   15.0                  NaN          Roger Voss
# 2           87   14.0    Willamette Valley        Paul Gregutt
# 3           87   13.0  Lake Michigan Shore  Alexander Peartree
# 4           87   65.0    Willamette Valley        Paul Gregutt
# ...        ...    ...                  ...                 ...
# 129966      90   28.0                  NaN  Anna Lee C. Iijima
# 129967      90   75.0               Oregon        Paul Gregutt
# 129968      90   30.0               Alsace          Roger Voss
# 129969      90   32.0               Alsace          Roger Voss
# 129970      90   21.0               Alsace          Roger Voss
#
#                                                     title  year price_range  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)  2013         NaN
# ...

# %%
data.drop_duplicates()
# Out:
#         Unnamed: 0  points  price             region_1         taster_name  \
# 0                0      87    NaN                 Etna       Kerin O’Keefe
# 1                1      87   15.0                  NaN          Roger Voss
# 2                2      87   14.0    Willamette Valley        Paul Gregutt
# 3                3      87   13.0  Lake Michigan Shore  Alexander Peartree
# 4                4      87   65.0    Willamette Valley        Paul Gregutt
# ...            ...     ...    ...                  ...                 ...
# 129966      129966      90   28.0                  NaN  Anna Lee C. Iijima
# 129967      129967      90   75.0               Oregon        Paul Gregutt
# 129968      129968      90   30.0               Alsace          Roger Voss
# 129969      129969      90   32.0               Alsace          Roger Voss
# 129970      129970      90   21.0               Alsace          Roger Voss
#
# ...

# %%
print(data.dtypes)
# Out:
# Unnamed: 0             int64
# points                 int64
# price                float64
# region_1              object
# taster_name           object
#                       ...
# variety_Zinfandel       bool
# variety_Zlahtina        bool
# variety_Zweigelt        bool
# variety_Çalkarası       bool
# variety_Žilavka         bool
# Length: 1180, dtype: object

# %%
print(data.head())
# Out:
#    Unnamed: 0  points  price             region_1         taster_name  \
# 0           0      87    NaN                 Etna       Kerin O’Keefe
# 1           1      87   15.0                  NaN          Roger Voss
# 2           2      87   14.0    Willamette Valley        Paul Gregutt
# 3           3      87   13.0  Lake Michigan Shore  Alexander Peartree
# 4           4      87   65.0    Willamette Valley        Paul Gregutt
#
#                                                title  year price_range  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)  2013         NaN
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  2011         Low
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)  2013         Low
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...  2013         Low
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...  2012        High
#
#    country_Armenia  country_Australia  ...  variety_Yapincak  variety_Zelen  \
# ...

# %%
data.drop_duplicates(inplace=True)
