# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrices import accuracy_score
from sklearn.metrices import meansquared

# %%
"C:\Users\BHARGAVI\OneDrive\Documents\all_season_details.csv"

# %%
df=pd.read_csv(r"C:\Users\BHARGAVI\OneDrive\Documents\all_season_details.csv")
# Out:
# C:\Users\BHARGAVI\AppData\Local\Temp\ipykernel_4220\139627852.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\BHARGAVI\OneDrive\Documents\all_season_details.csv")

# %%
df
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  ...  wicket_id  \
# 0                  CSK           1     1     1  ...        NaN
# ...

# %%
print(df.head())
# Out:
#    comment_id  season  match_id match_name home_team away_team  \
# 0         110  2023.0   1359475   GT v CSK        GT       CSK
# 1         120  2023.0   1359475   GT v CSK        GT       CSK
# 2         130  2023.0   1359475   GT v CSK        GT       CSK
# 3         140  2023.0   1359475   GT v CSK        GT       CSK
# 4         150  2023.0   1359475   GT v CSK        GT       CSK
#
#   current_innings  innings_id  over  ball  ...  wicket_id wkt_batsman_name  \
# 0             CSK           1     1     1  ...        NaN              NaN
# 1             CSK           1     1     2  ...        NaN              NaN
# 2             CSK           1     1     3  ...        NaN              NaN
# 3             CSK           1     1     4  ...        NaN              NaN
# 4             CSK           1     1     5  ...        NaN              NaN
#
#    wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  wkt_text  \
# ...

# %%
x=df[['over','wicket_id']]
y=df['wkt_batsman_runs']

# %%
x
# Out:
#         over  wicket_id
# 0          1        NaN
# 1          1        NaN
# 2          1        NaN
# 3          1        NaN
# 4          1        NaN
# ...      ...        ...
# 242545    20        NaN
# 242546    20        NaN
# 242547    20        NaN
# 242548    20        NaN
# 242549    20        NaN
#
# [242550 rows x 2 columns]

# %%
y
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 242545   NaN
# 242546   NaN
# 242547   NaN
# 242548   NaN
# 242549   NaN
# Name: wkt_batsman_runs, Length: 242550, dtype: float64

# %%
split=0.8
train_size=int((len(df))*split)

# %%
train_data=data[:train_size]
test_data=data[train_size:]

# %%
train_data
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 194035      117060  2011.0    501240   CSK v RR       CSK        RR
# 194036      117070  2011.0    501240   CSK v RR       CSK        RR
# 194037      118010  2011.0    501240   CSK v RR       CSK        RR
# 194038      118020  2011.0    501240   CSK v RR       CSK        RR
# 194039      118030  2011.0    501240   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  ...  wicket_id  \
# 0                  CSK           1     1     1  ...        NaN
# ...

# %%
test_data
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 194040      118040  2011.0    501240   CSK v RR       CSK        RR
# 194041      118050  2011.0    501240   CSK v RR       CSK        RR
# 194042      118060  2011.0    501240   CSK v RR       CSK        RR
# 194043      119010  2011.0    501240   CSK v RR       CSK        RR
# 194044      119020  2011.0    501240   CSK v RR       CSK        RR
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  ...  wicket_id  \
# 194040              RR           1    19     4  ...    38699.0
# ...

# %%
x_train, x_test,y_train ,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_train
# Out:
#         over  wicket_id
# 199032    12        NaN
# 237647    17        NaN
# 10462      1        NaN
# 39475      8        NaN
# 137928     9        NaN
# ...      ...        ...
# 119879    10   219889.0
# 103694    12        NaN
# 131932     5        NaN
# 146867    18        NaN
# 121958    10        NaN
#
# [194040 rows x 2 columns]

# %%
x_test
# Out:
#         over  wicket_id
# 122566    10        NaN
# 147656     5        NaN
# 27099     20        NaN
# 42493      2        NaN
# 154359    18        NaN
# ...      ...        ...
# 19877     17        NaN
# 217199    14        NaN
# 188029     2        NaN
# 220380    14        NaN
# 8762       5        NaN
#
# [48510 rows x 2 columns]

# %%
y_train
# Out:
# 199032     NaN
# 237647     NaN
# 10462      NaN
# 39475      NaN
# 137928     NaN
#           ...
# 119879    28.0
# 103694     NaN
# 131932     NaN
# 146867     NaN
# 121958     NaN
# Name: wkt_batsman_runs, Length: 194040, dtype: float64

# %%
y_test
# Out:
# 122566   NaN
# 147656   NaN
# 27099    NaN
# 42493    NaN
# 154359   NaN
#           ..
# 19877    NaN
# 217199   NaN
# 188029   NaN
# 220380   NaN
# 8762     NaN
# Name: wkt_batsman_runs, Length: 48510, dtype: float64

# %%
data.shape
# Out:
# (242550, 45)

# %%
rf_model=RandomForestClassifier(n_estimators=200,max_depth=None,random_state=42)
rf_model
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
rf_simple_mse=mean_squared_error(y_test,y_pred)
rf_r2=r2_score(y_test,y_pred)

# %%
data1=pd.DataFrame({
    'overs_bowled':[10],
    'wickets_lost':[0],
    'run_rate':[10],
    'powerplay':[0]
})

# %%
data1
# Out:
#    overs_bowled  wickets_lost  run_rate  powerplay
# 0            10             0        10          0

# %%
runp=rf_model.predict(new_data)
runp

# %%
array([102.9])
